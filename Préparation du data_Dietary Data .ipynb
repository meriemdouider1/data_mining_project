# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/data_mining_project/blob/main/Pr%C3%A9paration%20du%20data_Dietary%20Data%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# *DR1TOT_J*:

# %%
data_1 = '/content/DR1TOT_J.xlsx'

# %%
d1= pd.read_excel(data_1,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d1.head()
# Out:
#     SEQN        WTDRD1        WTDR2D  ...  DRD370U  DRD370UQ  DRD370V
# 0  93703      0.000000           NaN  ...      NaN       NaN      NaN
# 1  93704  81714.005497  82442.869214  ...      2.0       NaN      2.0
# 2  93705   7185.560737   5640.391078  ...      NaN       NaN      NaN
# 3  93706   6463.882999      0.000000  ...      2.0       NaN      2.0
# 4  93707  15333.776805  22707.066970  ...      NaN       NaN      NaN
#
# [5 rows x 168 columns]

# %%
len(d1)
# Out:
# 8704

# %% [markdown]
# *DS1IDS_J*

# %%
data_2 = '/content/DS1IDS_J.xlsx'

# %%
d2= pd.read_excel(data_2,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d2.head()
# Out:
#     SEQN       WTDRD1       WTDR2D  ...  DS1ISELE  DS1ICAFF  DS1IIODI
# 0  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 1  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 2  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 3  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 4  93705  7185.560737  5640.391078  ...       4.1       NaN       NaN
#
# [5 rows x 49 columns]

# %%
len(d2)
# Out:
# 6068

# %%
dd = pd.merge(d1,d2)

# %%
len(dd)
# Out:
# 6068

# %% [markdown]
# *DS1TOT_J*

# %%
data_3 = '/content/DS1TOT_J.xlsx'

# %%
d3= pd.read_excel(data_3,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d3.head()
# Out:
#     SEQN        WTDRD1        WTDR2D  ...  DS1TSELE  DS1TCAFF  DS1TIODI
# 0  93703      0.000000           NaN  ...       NaN       NaN       NaN
# 1  93704  81714.005497  82442.869214  ...       NaN       NaN       NaN
# 2  93705   7185.560737   5640.391078  ...      24.0       NaN     150.0
# 3  93706   6463.882999      0.000000  ...       NaN       NaN       NaN
# 4  93707  15333.776805  22707.066970  ...       NaN       NaN       NaN
#
# [5 rows x 49 columns]

# %%
len(d3)
# Out:
# 8704

# %% [markdown]
# *DS2IDS_J*

# %%
data_4 = '/content/DS2IDS_J.xlsx'

# %%
d4= pd.read_excel(data_4,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d4.head()
# Out:
#     SEQN       WTDRD1       WTDR2D  ...  DS2ISELE  DS2ICAFF  DS2IIODI
# 0  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 1  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 2  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 3  93705  7185.560737  5640.391078  ...       NaN       NaN       NaN
# 4  93705  7185.560737  5640.391078  ...       4.1       NaN       NaN
#
# [5 rows x 49 columns]

# %%
len(d4)
# Out:
# 5776

# %%
dd2 = pd.merge(d3,d4)

# %%
len(dd2)
# Out:
# 5776

# %%
dd3=pd.merge(dd2,dd)

# %%
len(dd3)
# Out:
# 4521

# %% [markdown]
# *DS2TOT_J*

# %%
data_5 = '/content/DS2TOT_J.xlsx'
d5= pd.read_excel(data_5,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d5)
# Out:
# 8704

# %%
dd4=pd.merge(dd3,d5)

# %%
len(dd4)
# Out:
# 4521

# %% [markdown]
# *DSQIDS_J*

# %%
data_6 = '/content/DSQIDS_J.xlsx'
d6= pd.read_excel(data_6,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d6)
# Out:
# 9984

# %%
dd5=pd.merge(dd4,d6)

# %%
len(dd5)
# Out:
# 4012

# %% [markdown]
# *DSQTOT_J*

# %%
data_7 = '/content/DSQTOT_J.xlsx'
d7= pd.read_excel(data_7,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d7)
# Out:
# 9254

# %%
dd6=pd.merge(dd5,d7)

# %%
len(dd6)
# Out:
# 4012

# %%
# writing to Excel 
datatoexcel = pd.ExcelWriter('Dietary_Data.xlsx') 
  
# write DataFrame to excel 
dd6.to_excel(datatoexcel) 
  
# save the excel 
datatoexcel.save()

# %% [markdown]
# #### affichage data final

# %%
data_f = '/content/Dietary_Data.xlsx'
df= pd.read_excel(data_f,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(df)
# Out:
# 4012

# %%
df.head()
# Out:
#    Unnamed: 0   SEQN       WTDRD1  ...  DSQTSELE  DSQTCAFF  DSQTIODI
# 0           0  93705  7185.560737  ...      21.4       NaN     150.0
# 1           1  93705  7185.560737  ...      21.4       NaN     150.0
# 2           2  93705  7185.560737  ...      21.4       NaN     150.0
# 3           3  93705  7185.560737  ...      21.4       NaN     150.0
# 4           4  93705  7185.560737  ...      21.4       NaN     150.0
#
# [5 rows x 453 columns]
