# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/data_mining_project/blob/main/data_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_1 = '/content/DEMO_J.xlsx'
Demo_data= pd.read_excel(data_1,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(Demo_data)
# Out:
# 9254

# %%
Demo_data.head()
# Out:
#     SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  ...  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# 0  93703        10         2         2  ...       145      15.0      15.0      5.00
# 1  93704        10         2         1  ...       143      15.0      15.0      5.00
# 2  93705        10         2         2  ...       145       3.0       3.0      0.82
# 3  93706        10         2         1  ...       134       NaN       NaN       NaN
# 4  93707        10         2         1  ...       138      10.0      10.0      1.88
#
# [5 rows x 46 columns]

# %%
data_2 = '/content/DIQ_J.xlsx'
Quest_data= pd.read_excel(data_2,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(Quest_data)
# Out:
# 8897

# %%
d1=pd.merge(Quest_data,Demo_data)

# %%
len(d1)
# Out:
# 8897

# %%
data_3 = '/content/Dietary_Data.xlsx'
Dietary_data= pd.read_excel(data_3,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(Dietary_data)
# Out:
# 4012

# %%
d2=pd.merge(d1,Dietary_data)

# %%
len(d2)
# Out:
# 3987

# %%
data_4 = '/content/Examination Data.xlsx'
Examination_data= pd.read_excel(data_4,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(Examination_data)
# Out:
# 880

# %%
d3=pd.merge(d2,Examination_data)

# %%
len(d3)
# Out:
# 0

# %%
data_5 = '/content/Laboratory Data.xlsx'
labo_data= pd.read_excel(data_5,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(labo_data)
# Out:
# 1175

# %%
labo_data.head()
# Out:
#    Unnamed: 0   SEQN       WTFOL2YR  ...  LBXVIC  LBDVICSI  LBDVICLC
# 0           0  93711   30515.406501  ...   1.520     86.30       0.0
# 1           1  93718   41525.006962  ...   2.050    116.00       0.0
# 2           2  93731   59175.193015  ...   0.698     39.60       0.0
# 3           3  93735   24316.425101  ...   0.071      4.03       0.0
# 4           4  93738  124528.616043  ...   0.486     27.60       0.0
#
# [5 rows x 87 columns]

# %%
d4=pd.merge(d2,labo_data)

# %%
len(d4)
# Out:
# 0
