# %% [markdown]
# <a href="https://colab.research.google.com/github/meriemdouider1/data_mining_project/blob/main/Pr%C3%A9paration%20du%20data_que%20Data%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# *Diabetes*:

# %%
data_1 = '/content/DIQ_J.xlsx'

# %%
d1= pd.read_excel(data_1,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d1.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  DID350  DIQ350U  DIQ360  DIQ080
# 0  93703       2     NaN     NaN  ...     NaN      NaN     NaN     NaN
# 1  93704       2     NaN     NaN  ...     NaN      NaN     NaN     NaN
# 2  93705       2     NaN     2.0  ...     NaN      NaN     NaN     NaN
# 3  93706       2     NaN     2.0  ...     NaN      NaN     NaN     NaN
# 4  93707       2     NaN     2.0  ...     NaN      NaN     NaN     NaN
#
# [5 rows x 54 columns]

# %%
len(d1)
# Out:
# 8897

# %% [markdown]
# *Acculturation*

# %%
data_2 = '/content/ACQ_J.xlsx'

# %%
d2= pd.read_excel(data_2,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d2.head()
# Out:
#     SEQN  ACD011A  ACD011B  ACD011C  ACD040  ACD110
# 0  93705      1.0      NaN      NaN     NaN     NaN
# 1  93706      NaN      NaN      NaN     NaN     4.0
# 2  93707      1.0      NaN      NaN     NaN     NaN
# 3  93708      NaN      NaN      NaN     NaN     1.0
# 4  93709      1.0      NaN      NaN     NaN     NaN

# %%
len(d2)
# Out:
# 8421

# %%
dd = pd.merge(d1,d2,how='outer')

# %%
len(dd)
# Out:
# 8897

# %%
dd.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  ACD011B  ACD011C  ACD040  ACD110
# 0  93703       2     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 1  93704       2     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 2  93705       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
# 3  93706       2     NaN     2.0  ...      NaN      NaN     NaN     4.0
# 4  93707       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# *Alcohol Use*

# %%
data_3 = '/content/ALQ_J.xlsx'

# %%
d3= pd.read_excel(data_3,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d3.head()
# Out:
#     SEQN  ALQ111  ALQ121  ALQ130  ...  ALQ280  ALQ290  ALQ151  ALQ170
# 0  93705     1.0     7.0     1.0  ...     NaN     NaN     2.0     5.0
# 1  93706     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93708     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 3  93709     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 4  93711     1.0     5.0     1.0  ...     NaN     NaN     2.0     0.0
#
# [5 rows x 10 columns]

# %%
len(d3)
# Out:
# 5533

# %%
dd2 = pd.merge(dd,d3,how='outer')

# %%
len(dd2)
# Out:
# 8897

# %%
dd2.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  ALQ280  ALQ290  ALQ151  ALQ170
# 0  93703       2     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1  93704       2     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93705       2     NaN     2.0  ...     NaN     NaN     2.0     5.0
# 3  93706       2     NaN     2.0  ...     NaN     NaN     NaN     NaN
# 4  93707       2     NaN     2.0  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 68 columns]

# %% [markdown]
# *Audiometry*

# %%
data_4 = '/content/AUQ_J.xlsx'

# %%
d4= pd.read_excel(data_4,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)

# %%
d4.head()
# Out:
#     SEQN  AUQ054  AUQ060  AUQ070  ...  AUQ360  AUQ370  AUQ510  AUQ380
# 0  93703       1     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1  93704       1     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93705       2     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 3  93706       1     NaN     NaN  ...     NaN     2.0     NaN     6.0
# 4  93707       1     NaN     NaN  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 58 columns]

# %%
len(d4)
# Out:
# 8897

# %%
dd3 = pd.merge(dd2,d4,how='outer')

# %%
len(dd3)
# Out:
# 8897

# %%
dd3.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  AUQ360  AUQ370  AUQ510  AUQ380
# 0  93703       2     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1  93704       2     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93705       2     NaN     2.0  ...     NaN     NaN     NaN     NaN
# 3  93706       2     NaN     2.0  ...     NaN     2.0     NaN     6.0
# 4  93707       2     NaN     2.0  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 125 columns]

# %% [markdown]
# *Blood Pressure & Cholesterol*

# %%
data_5 = '/content/BPQ_J.xlsx'
d5= pd.read_excel(data_5,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d5)
# Out:
# 6161

# %%
d5.head()
# Out:
#     SEQN  BPQ020  BPQ030  BPD035  ...  BPQ060  BPQ070  BPQ090D  BPQ100D
# 0  93705       1     1.0    50.0  ...     1.0     2.0      2.0      NaN
# 1  93706       2     NaN     NaN  ...     1.0     2.0      2.0      NaN
# 2  93708       1     1.0    50.0  ...     NaN     1.0      1.0      1.0
# 3  93709       1     1.0    71.0  ...     1.0     2.0      2.0      NaN
# 4  93711       2     NaN     NaN  ...     NaN     1.0      1.0      2.0
#
# [5 rows x 11 columns]

# %%
dd4 = pd.merge(dd3,d5,how='outer')

# %%
len(dd4)
# Out:
# 8897

# %%
dd4.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  BPQ060  BPQ070  BPQ090D  BPQ100D
# 0  93703       2     NaN     NaN  ...     NaN     NaN      NaN      NaN
# 1  93704       2     NaN     NaN  ...     NaN     NaN      NaN      NaN
# 2  93705       2     NaN     2.0  ...     1.0     2.0      2.0      NaN
# 3  93706       2     NaN     2.0  ...     1.0     2.0      2.0      NaN
# 4  93707       2     NaN     2.0  ...     NaN     NaN      NaN      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# *Cardiovascular Health*

# %%
data_6 = '/content/CDQ_J.xlsx'
d6= pd.read_excel(data_6,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d6)
# Out:
# 3882

# %%
d6.head()
# Out:
#     SEQN  CDQ001  CDQ002  CDQ003  ...  CDQ009G  CDQ009H  CDQ008  CDQ010
# 0  93705       2     NaN     NaN  ...      NaN      NaN     NaN       2
# 1  93708       2     NaN     NaN  ...      NaN      NaN     NaN       2
# 2  93709       2     NaN     NaN  ...      NaN      NaN     NaN       2
# 3  93711       2     NaN     NaN  ...      NaN      NaN     NaN       2
# 4  93713       2     NaN     NaN  ...      NaN      NaN     NaN       1
#
# [5 rows x 17 columns]

# %%
dd5 = pd.merge(dd4,d6,how='outer')

# %%
len(dd5)
# Out:
# 8897

# %%
dd5.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  CDQ009G  CDQ009H  CDQ008  CDQ010
# 0  93703       2     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 1  93704       2     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 2  93705       2     NaN     2.0  ...      NaN      NaN     NaN     2.0
# 3  93706       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
# 4  93707       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
#
# [5 rows x 151 columns]

# %% [markdown]
# *Current Health Status*

# %%
data_7 = '/content/HSQ_J.xlsx'
d7= pd.read_excel(data_7,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d7)
# Out:
# 8366

# %%
d7.head()
# Out:
#     SEQN  HSD010  HSQ500  HSQ510  HSQ520  HSQ571  HSQ580  HSQ590  HSAQUEX
# 0  93703     NaN     NaN     NaN     NaN     NaN     NaN     NaN        1
# 1  93704     NaN     2.0     2.0     2.0     NaN     NaN     NaN        1
# 2  93705     3.0     2.0     2.0     2.0     2.0     NaN     1.0        2
# 3  93706     2.0     2.0     2.0     2.0     1.0     5.0     2.0        2
# 4  93707     3.0     2.0     2.0     2.0     NaN     NaN     NaN        2

# %%
dd6 = pd.merge(dd5,d7,how='outer')

# %%
len(dd6)
# Out:
# 8897

# %%
dd6.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  HSQ571  HSQ580  HSQ590  HSAQUEX
# 0  93703       2     NaN     NaN  ...     NaN     NaN     NaN      1.0
# 1  93704       2     NaN     NaN  ...     NaN     NaN     NaN      1.0
# 2  93705       2     NaN     2.0  ...     2.0     NaN     1.0      2.0
# 3  93706       2     NaN     2.0  ...     1.0     5.0     2.0      2.0
# 4  93707       2     NaN     2.0  ...     NaN     NaN     NaN      2.0
#
# [5 rows x 159 columns]

# %% [markdown]
# *Dermatology*

# %%
data_8 = '/content/DEQ_J.xlsx'
d8= pd.read_excel(data_8,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d8)
# Out:
# 3419

# %%
d8.head()
# Out:
#     SEQN  DED031  DEQ034A  DEQ034C  DEQ034D  DEQ038G  DEQ038Q  DED120  DED125
# 0  93711     3.0      4.0      4.0      5.0      2.0      NaN    60.0   300.0
# 1  93714     5.0      3.0      3.0      5.0      2.0      NaN   120.0   300.0
# 2  93717     3.0      3.0      3.0      5.0      1.0      1.0  3333.0   240.0
# 3  93718     5.0      3.0      3.0      5.0      2.0      NaN  3333.0   240.0
# 4  93728     4.0      3.0      4.0      3.0      1.0      1.0    60.0    60.0

# %%
dd7 = pd.merge(dd6,d8,how='outer')

# %%
len(dd7)
# Out:
# 8897

# %%
dd7.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  DEQ038G  DEQ038Q  DED120  DED125
# 0  93703       2     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 1  93704       2     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 2  93705       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
# 3  93706       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
# 4  93707       2     NaN     2.0  ...      NaN      NaN     NaN     NaN
#
# [5 rows x 167 columns]

# %% [markdown]
# *Diet Behavior & Nutrition*

# %%
data_9 = '/content/DBQ_J.xlsx'
d9= pd.read_excel(data_9,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d9)
# Out:
# 9254

# %%
d9.head()
# Out:
#     SEQN  DBQ010  DBD030  DBD041  ...  DBQ930  DBQ935  DBQ940  DBQ945
# 0  93703     1.0   273.0     1.0  ...     NaN     NaN     NaN     NaN
# 1  93704     1.0    60.0     3.0  ...     NaN     NaN     NaN     NaN
# 2  93705     NaN     NaN     NaN  ...     1.0     2.0     1.0     2.0
# 3  93706     NaN     NaN     NaN  ...     2.0     1.0     2.0     1.0
# 4  93707     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 46 columns]

# %%
dd8 = pd.merge(dd7,d9,how='outer')

# %%
len(dd8)
# Out:
# 9254

# %%
dd8.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  DBQ930  DBQ935  DBQ940  DBQ945
# 0  93703     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1  93704     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93705     2.0     NaN     2.0  ...     1.0     2.0     1.0     2.0
# 3  93706     2.0     NaN     2.0  ...     2.0     1.0     2.0     1.0
# 4  93707     2.0     NaN     2.0  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 212 columns]

# %% [markdown]
# *Disability*

# %%
data_10 = '/content/DBQ_J.xlsx'
d10= pd.read_excel(data_10,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d10)
# Out:
# 9254

# %%
d10.head()
# Out:
#     SEQN  DBQ010  DBD030  DBD041  ...  DBQ930  DBQ935  DBQ940  DBQ945
# 0  93703     1.0   273.0     1.0  ...     NaN     NaN     NaN     NaN
# 1  93704     1.0    60.0     3.0  ...     NaN     NaN     NaN     NaN
# 2  93705     NaN     NaN     NaN  ...     1.0     2.0     1.0     2.0
# 3  93706     NaN     NaN     NaN  ...     2.0     1.0     2.0     1.0
# 4  93707     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 46 columns]

# %%
dd9 = pd.merge(dd8,d10,how='outer')

# %%
len(dd9)
# Out:
# 9254

# %%
dd9.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  DBQ930  DBQ935  DBQ940  DBQ945
# 0  93703     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1  93704     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93705     2.0     NaN     2.0  ...     1.0     2.0     1.0     2.0
# 3  93706     2.0     NaN     2.0  ...     2.0     1.0     2.0     1.0
# 4  93707     2.0     NaN     2.0  ...     NaN     NaN     NaN     NaN
#
# [5 rows x 212 columns]

# %% [markdown]
# *Drug Use*

# %%
data_11 = '/content/DUQ_J.xlsx'
d11= pd.read_excel(data_11,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d11)
# Out:
# 4572

# %%
d11.head()
# Out:
#     SEQN  DUQ200  DUQ210  DUQ211  ...  DUQ400U  DUQ410  DUQ420  DUQ430
# 0  93705     NaN     NaN     NaN  ...      NaN     NaN     NaN     NaN
# 1  93706     2.0     NaN     NaN  ...      NaN     NaN     NaN     NaN
# 2  93708     NaN     NaN     NaN  ...      NaN     NaN     NaN     NaN
# 3  93711     2.0     NaN     NaN  ...      NaN     NaN     NaN     NaN
# 4  93712     1.0    18.0     2.0  ...      NaN     NaN     NaN     2.0
#
# [5 rows x 41 columns]

# %%
dd10 = pd.merge(dd9,d11,how='outer')

# %%
len(dd10)
# Out:
# 9254

# %%
dd10.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  DUQ400U  DUQ410  DUQ420  DUQ430
# 0  93703     2.0     NaN     NaN  ...      NaN     NaN     NaN     NaN
# 1  93704     2.0     NaN     NaN  ...      NaN     NaN     NaN     NaN
# 2  93705     2.0     NaN     2.0  ...      NaN     NaN     NaN     NaN
# 3  93706     2.0     NaN     2.0  ...      NaN     NaN     NaN     NaN
# 4  93707     2.0     NaN     2.0  ...      NaN     NaN     NaN     NaN
#
# [5 rows x 252 columns]

# %% [markdown]
# *Early Childhood*

# %%
data_12 = '/content/ECQ_J.xlsx'
d12= pd.read_excel(data_12,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d12)
# Out:
# 3093

# %%
d12.head()
# Out:
#     SEQN  ECD010  ECQ020  ECD070A  ...  ECQ090  WHQ030E  MCQ080E  ECQ150
# 0  93703    35.0     2.0      8.0  ...     NaN      3.0      2.0     NaN
# 1  93704    29.0     2.0      7.0  ...     NaN      3.0      2.0     NaN
# 2  93707    34.0     2.0      7.0  ...     NaN      3.0      2.0     NaN
# 3  93710    28.0     2.0      7.0  ...     NaN      NaN      NaN     NaN
# 4  93719    25.0     2.0      5.0  ...     NaN      3.0      1.0     2.0
#
# [5 rows x 10 columns]

# %%
dd11 = pd.merge(dd10,d12,how='outer')

# %%
len(dd11)
# Out:
# 9254

# %%
dd11.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  ECQ090  WHQ030E  MCQ080E  ECQ150
# 0  93703     2.0     NaN     NaN  ...     NaN      3.0      2.0     NaN
# 1  93704     2.0     NaN     NaN  ...     NaN      3.0      2.0     NaN
# 2  93705     2.0     NaN     2.0  ...     NaN      NaN      NaN     NaN
# 3  93706     2.0     NaN     2.0  ...     NaN      NaN      NaN     NaN
# 4  93707     2.0     NaN     2.0  ...     NaN      3.0      2.0     NaN
#
# [5 rows x 261 columns]

# %% [markdown]
# *Health Insurance*

# %%
data_13 = '/content/HIQ_J.xlsx'
d13= pd.read_excel(data_13,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d13)
# Out:
# 9254

# %%
d13.head()
# Out:
#     SEQN  HIQ011  HIQ031A  HIQ031B  ...  HIQ260  HIQ105  HIQ270  HIQ210
# 0  93703       1     14.0      NaN  ...     NaN     NaN     1.0     2.0
# 1  93704       1     14.0      NaN  ...     NaN     NaN     1.0     2.0
# 2  93705       1      NaN     15.0  ...     NaN     1.0     1.0     2.0
# 3  93706       1     14.0      NaN  ...     NaN     NaN     1.0     2.0
# 4  93707       1      NaN      NaN  ...     NaN     NaN     1.0     2.0
#
# [5 rows x 16 columns]

# %%
dd12 = pd.merge(dd11,d13,how='outer')

# %%
len(dd12)
# Out:
# 9254

# %%
dd12.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  HIQ260  HIQ105  HIQ270  HIQ210
# 0  93703     2.0     NaN     NaN  ...     NaN     NaN     1.0     2.0
# 1  93704     2.0     NaN     NaN  ...     NaN     NaN     1.0     2.0
# 2  93705     2.0     NaN     2.0  ...     NaN     1.0     1.0     2.0
# 3  93706     2.0     NaN     2.0  ...     NaN     NaN     1.0     2.0
# 4  93707     2.0     NaN     2.0  ...     NaN     NaN     1.0     2.0
#
# [5 rows x 276 columns]

# %% [markdown]
# *Hepatitis*

# %%
data_14 = '/content/HEQ_J.xlsx'
d14= pd.read_excel(data_14,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d14)
# Out:
# 7878

# %%
d14.head()
# Out:
#     SEQN  HEQ010  HEQ020  HEQ030  HEQ040
# 0  93705       2     NaN       2     NaN
# 1  93706       2     NaN       2     NaN
# 2  93707       2     NaN       2     NaN
# 3  93708       2     NaN       2     NaN
# 4  93709       2     NaN       2     NaN

# %%
dd13 = pd.merge(dd12,d14,how='outer')

# %%
len(dd13)
# Out:
# 9254

# %%
dd13.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  HEQ010  HEQ020  HEQ030  HEQ040
# 0  93703     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1  93704     2.0     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  93705     2.0     NaN     2.0  ...     2.0     NaN     2.0     NaN
# 3  93706     2.0     NaN     2.0  ...     2.0     NaN     2.0     NaN
# 4  93707     2.0     NaN     2.0  ...     2.0     NaN     2.0     NaN
#
# [5 rows x 280 columns]

# %% [markdown]
# *Hospital Utilization & Access to Care*

# %%
data_15 = '/content/HUQ_J.xlsx'
d15= pd.read_excel(data_15,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d15)
# Out:
# 9254

# %%
d15.head()
# Out:
#     SEQN  HUQ010  HUQ020  HUQ030  ...  HUQ061  HUQ071  HUD080  HUQ090
# 0  93703       1     3.0       1  ...     NaN       2     NaN     NaN
# 1  93704       1     3.0       1  ...     NaN       2     NaN     NaN
# 2  93705       3     3.0       1  ...     NaN       2     NaN     2.0
# 3  93706       1     3.0       1  ...     NaN       2     NaN     2.0
# 4  93707       3     3.0       1  ...     NaN       2     NaN     1.0
#
# [5 rows x 10 columns]

# %%
dd14 = pd.merge(dd13,d15,how='outer')

# %%
len(dd14)
# Out:
# 9254

# %%
dd14.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  HUQ061  HUQ071  HUD080  HUQ090
# 0  93703     2.0     NaN     NaN  ...     NaN       2     NaN     NaN
# 1  93704     2.0     NaN     NaN  ...     NaN       2     NaN     NaN
# 2  93705     2.0     NaN     2.0  ...     NaN       2     NaN     2.0
# 3  93706     2.0     NaN     2.0  ...     NaN       2     NaN     2.0
# 4  93707     2.0     NaN     2.0  ...     NaN       2     NaN     1.0
#
# [5 rows x 289 columns]

# %% [markdown]
# *Housing Characteristics*

# %%
data_16 = '/content/HOQ_J.xlsx'
d16= pd.read_excel(data_16,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d16)
# Out:
# 9254

# %%
d16.head()
# Out:
#     SEQN  HOD050  HOQ065
# 0  93703     6.0     1.0
# 1  93704    10.0     1.0
# 2  93705     3.0     2.0
# 3  93706     NaN     NaN
# 4  93707     9.0     1.0

# %%
dd15 = pd.merge(dd14,d16,how='outer')

# %%
len(dd15)
# Out:
# 9254

# %%
dd15.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  HUD080  HUQ090  HOD050  HOQ065
# 0  93703     2.0     NaN     NaN  ...     NaN     NaN     6.0     1.0
# 1  93704     2.0     NaN     NaN  ...     NaN     NaN    10.0     1.0
# 2  93705     2.0     NaN     2.0  ...     NaN     2.0     3.0     2.0
# 3  93706     2.0     NaN     2.0  ...     NaN     2.0     NaN     NaN
# 4  93707     2.0     NaN     2.0  ...     NaN     1.0     9.0     1.0
#
# [5 rows x 291 columns]

# %% [markdown]
# *Immunization*

# %%
data_17 = '/content/IMQ_J.xlsx'
d17= pd.read_excel(data_17,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d17)
# Out:
# 9254

# %%
d17.head()
# Out:
#     SEQN  IMQ011  IMQ020  IMQ060  ...  IMQ081C  IMQ081D  IMQ090  IMQ100
# 0  93703     1.0       1     NaN  ...      NaN      NaN     NaN     NaN
# 1  93704     3.0       1     NaN  ...      NaN      NaN     NaN     NaN
# 2  93705     3.0       3     NaN  ...      NaN      NaN     NaN     NaN
# 3  93706     1.0       1     NaN  ...      NaN      NaN     NaN     NaN
# 4  93707     1.0       1     NaN  ...      NaN      NaN     NaN     NaN
#
# [5 rows x 11 columns]

# %%
dd16 = pd.merge(dd15,d17,how='outer')

# %%
len(dd16)
# Out:
# 9254

# %%
dd16.head()
# Out:
#     SEQN  DIQ010  DID040  DIQ160  ...  IMQ081C  IMQ081D  IMQ090  IMQ100
# 0  93703     2.0     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 1  93704     2.0     NaN     NaN  ...      NaN      NaN     NaN     NaN
# 2  93705     2.0     NaN     2.0  ...      NaN      NaN     NaN     NaN
# 3  93706     2.0     NaN     2.0  ...      NaN      NaN     NaN     NaN
# 4  93707     2.0     NaN     2.0  ...      NaN      NaN     NaN     NaN
#
# [5 rows x 301 columns]

# %% [markdown]
# *Kidney Conditions - Urology*

# %%
data_18 = '/content/KIQ_U_J.xlsx'
d18= pd.read_excel(data_18,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(d18)
# Out:
# 5569

# %%
d18.head()
# Out:
#     SEQN  KIQ022  KIQ025  KIQ026  ...  KIQ470  KIQ050  KIQ052  KIQ480
# 0  93705       2     NaN       2  ...     NaN     1.0     1.0     2.0
# 1  93708       2     NaN       2  ...     NaN     1.0     1.0     3.0
# 2  93709       2     NaN       1  ...     NaN     NaN     NaN     NaN
# 3  93711       2     NaN       2  ...     NaN     NaN     NaN     3.0
# 4  93713       2     NaN       2  ...     NaN     NaN     NaN     0.0
#
# [5 rows x 16 columns]

# %%
dd17 = pd.merge(dd16,d18,how='outer')

# %%
# writing to Excel 
datatoexcel = pd.ExcelWriter('Dietary_Data.xlsx') 
  
# write DataFrame to excel 
dd6.to_excel(datatoexcel) 
  
# save the excel 
datatoexcel.save()

# %% [markdown]
# #### affichage data final

# %%
data_f = '/content/Dietary_Data.xlsx'
df= pd.read_excel(data_f,
sheet_name=0,
header=0,
index_col=False,
keep_default_na=True
)
len(df)
# Out:
# 4012

# %%
df.head()
# Out:
#    Unnamed: 0   SEQN       WTDRD1  ...  DSQTSELE  DSQTCAFF  DSQTIODI
# 0           0  93705  7185.560737  ...      21.4       NaN     150.0
# 1           1  93705  7185.560737  ...      21.4       NaN     150.0
# 2           2  93705  7185.560737  ...      21.4       NaN     150.0
# 3           3  93705  7185.560737  ...      21.4       NaN     150.0
# 4           4  93705  7185.560737  ...      21.4       NaN     150.0
#
# [5 rows x 453 columns]
